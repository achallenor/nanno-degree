# %% [markdown]
# Introduction
# Question 1
# Question 2
# Question ...
# Data Wrangle
# Data analysis
# Conclusion
# Limitation

# %% [markdown]
# Investigatnig a data set. Alex Challenor
#
# Data import:
# Data set is: -TMDb movie data
#
# Data location:
# https://www.google.com/url?q=https://d17h27t6h515a5.cloudfront.net/topher/2017/October/59dd1c4c_tmdb-movies/tmdb-movies.csv&sa=D&ust=1532469042115000
#
# Explanation of the data set:
# This data set contain data of 10866 diffrent films and key item of data about each one.

# %%
import numpy as np
import pandas as pd
import matplotlib as mp
from collections import Counter

master_data = pd.read_csv("tmdb-movies.csv")

# %%
master_data.head(3)
# Out:
#        id    imdb_id  popularity     budget     revenue      original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810      Jurassic World
# 1   76341  tt1392190   28.419936  150000000   378436354  Mad Max: Fury Road
# 2  262500  tt2908446   13.112507  110000000   295238201           Insurgent
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
#
#                                          homepage          director  \
# 0                   http://www.jurassicworld.com/   Colin Trevorrow
# 1                     http://www.madmaxmovie.com/     George Miller
# 2  http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
#
#                       tagline      ...       \
# 0           The park is open.      ...
# 1          What a Lovely Day.      ...
# 2  One Choice Can Destroy You      ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
# 2  Beatrice Prior must confront her inner demons ...     119
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15       5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15       6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...      3/18/15       2480
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
# 1           7.1          2015  1.379999e+08  3.481613e+08
# 2           6.3          2015  1.012000e+08  2.716190e+08
#
# [3 rows x 21 columns]

# %%
#find out how many data rows in data set.
len(master_data)
# Out:
# 10866

# %% [markdown]
# Introduction:
#
# I will use Jupyter Note book to investigate the data set and invesigate the follwing questions using python.
#
# Question 1 - What is the most common film genre over the years from 1960-2015. This will be my 1D question.
#
# Question 2 - What is the most common Film genre per year. This will be my 2D question.

# %% [markdown]
# Data Wrangling:
#
# To answer the questions i will need to "wrangle" the data to get it into a position where i can analyse it and draw a conclusion.
#
# The following tasks are conducted in code cells below:
#
# - Convert date into a time/date format
#     - Alow the python code to read the data as date format not a sting value
#
# - Spit out the diffrent genras from the Genres column
#     - The Genrea column is filled with many values in a "string type". I will split the genres up into indivisual values which will allow for analysis later in project.
#
# - Check for any Genre cells with no data in
#     - Use this knowledge when making a conclusion
#
# - Use "group by" to organise that data to allow a conclusion and graph to be made.

# %%
#change string to date format
master_data['release_date'] = pd.to_datetime(master_data['release_date'],)

master_data.head(3)
# Out:
#        id    imdb_id  popularity     budget     revenue      original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810      Jurassic World
# 1   76341  tt1392190   28.419936  150000000   378436354  Mad Max: Fury Road
# 2  262500  tt2908446   13.112507  110000000   295238201           Insurgent
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
#
#                                          homepage          director  \
# 0                   http://www.jurassicworld.com/   Colin Trevorrow
# 1                     http://www.madmaxmovie.com/     George Miller
# 2  http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
#
#                       tagline      ...       \
# 0           The park is open.      ...
# 1          What a Lovely Day.      ...
# 2  One Choice Can Destroy You      ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
# 2  Beatrice Prior must confront her inner demons ...     119
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...   2015-06-09       5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...   2015-05-13       6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...   2015-03-18       2480
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
# 1           7.1          2015  1.379999e+08  3.481613e+08
# 2           6.3          2015  1.012000e+08  2.716190e+08
#
# [3 rows x 21 columns]

# %%
pd.DataFrame(master_data['cast'].str.split('|').tolist())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-a97c3e75f3b9> in <module>()
# ----> 1 pd.DataFrame(master_data['cast'].str.split('|').tolist())
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     303                     if is_named_tuple(data[0]) and columns is None:
#     304                         columns = data[0]._fields
# --> 305                     arrays, columns = _to_arrays(data, columns, dtype=dtype)
#     306                     columns = _ensure_index(columns)
#     307
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\frame.py in _to_arrays(data, columns, coerce_float, dtype)
#    5517     if isinstance(data[0], (list, tuple)):
#    5518         return _list_to_arrays(data, columns, coerce_float=coerce_float,
# -> 5519                                dtype=dtype)
#    5520     elif isinstance(data[0], collections.Mapping):
#    5521         return _list_of_dict_to_arrays(data, columns,
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\frame.py in _list_to_arrays(data, columns, coerce_float, dtype)
#    5594     else:
#    5595         # list of lists
# -> 5596         content = list(lib.to_object_array(data).T)
#    5597     return _convert_object_array(content, columns, dtype=dtype,
#    5598                                  coerce_float=coerce_float)
#
# pandas\src\inference.pyx in pandas.lib.to_object_array (pandas\lib.c:66515)()
#
# TypeError: object of type 'float' has no len()

# %%
# shows how many rows have no Genre data in this column
master_data['genres'].isnull().sum()
# Out:
# 23

# %%
master_data_split = master_data["cast"].str.split("|") 
master_data_split.head()
# Out:
# 0    [Chris Pratt, Bryce Dallas Howard, Irrfan Khan...
# 1    [Tom Hardy, Charlize Theron, Hugh Keays-Byrne,...
# 2    [Shailene Woodley, Theo James, Kate Winslet, A...
# 3    [Harrison Ford, Mark Hamill, Carrie Fisher, Ad...
# 4    [Vin Diesel, Paul Walker, Jason Statham, Miche...
# Name: cast, dtype: object

# %%
master_data.head(3)
# Out:
#        id    imdb_id  popularity     budget     revenue      original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810      Jurassic World
# 1   76341  tt1392190   28.419936  150000000   378436354  Mad Max: Fury Road
# 2  262500  tt2908446   13.112507  110000000   295238201           Insurgent
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
#
#                                          homepage          director  \
# 0                   http://www.jurassicworld.com/   Colin Trevorrow
# 1                     http://www.madmaxmovie.com/     George Miller
# 2  http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
#
#                       tagline      ...       \
# 0           The park is open.      ...
# 1          What a Lovely Day.      ...
# 2  One Choice Can Destroy You      ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
# 2  Beatrice Prior must confront her inner demons ...     119
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...   2015-06-09       5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...   2015-05-13       6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...   2015-03-18       2480
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
# 1           7.1          2015  1.379999e+08  3.481613e+08
# 2           6.3          2015  1.012000e+08  2.716190e+08
#
# [3 rows x 21 columns]

# %%
(master_data.set_index(['cast'])
   .apply(lambda x: x.str.split('|').explode())
   .reset_index())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-183884289170> in <module>()
#       1 (master_data.set_index(['cast'])
# ----> 2    .apply(lambda x: x.str.split('|').explode())
#       3    .reset_index())
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4150                     if reduce is None:
#    4151                         reduce = True
# -> 4152                     return self._apply_standard(f, axis, reduce=reduce)
#    4153             else:
#    4154                 return self._apply_broadcast(f, axis)
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4246             try:
#    4247                 for i, v in enumerate(series_gen):
# -> 4248                     results[i] = func(v)
#    4249                     keys.append(v.name)
#    4250             except Exception as e:
#
# <ipython-input-9-183884289170> in <lambda>(x)
#       1 (master_data.set_index(['cast'])
# ----> 2    .apply(lambda x: x.str.split('|').explode())
#       3    .reset_index())
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2738         if (name in self._internal_names_set or name in self._metadata or
#    2739                 name in self._accessors):
# -> 2740             return object.__getattribute__(self, name)
#    2741         else:
#    2742             if name in self._info_axis:
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\base.py in __get__(self, instance, owner)
#     239             # this ensures that Series.str.<method> is well defined
#     240             return self.accessor_cls
# --> 241         return self.construct_accessor(instance)
#     242
#     243     def __set__(self, instance, value):
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\strings.py in _make_str_accessor(self)
#    1839             # (instead of test for object dtype), but that isn't practical for
#    1840             # performance reasons until we have a str dtype (GH 9343)
# -> 1841             raise AttributeError("Can only use .str accessor with string "
#    1842                                  "values, which use np.object_ dtype in "
#    1843                                  "pandas")
#
# AttributeError: ('Can only use .str accessor with string values, which use np.object_ dtype in pandas', u'occurred at index id')

# %%
#create a new table with the genre data delimitd and split

data_with_genres_split = master_data["genres"].str.split("|", n = 9, expand = True) 
data_with_genres_split.head(5)
# Out:
#            0                1                2         3     4
# 0     Action        Adventure  Science Fiction  Thriller  None
# 1     Action        Adventure  Science Fiction  Thriller  None
# 2  Adventure  Science Fiction         Thriller      None  None
# 3     Action        Adventure  Science Fiction   Fantasy  None
# 4     Action            Crime         Thriller      None  None

# %%
#create a new table with the cast data delimitd and split

cast_names_split = master_data["cast"].str.split("|", n = 6, expand = True)

cast_names_split.head()
# Out:
#                   0                    1                 2  \
# 0       Chris Pratt  Bryce Dallas Howard       Irrfan Khan
# 1         Tom Hardy      Charlize Theron  Hugh Keays-Byrne
# 2  Shailene Woodley           Theo James      Kate Winslet
# 3     Harrison Ford          Mark Hamill     Carrie Fisher
# 4        Vin Diesel          Paul Walker     Jason Statham
#
#                     3               4
# 0   Vincent D'Onofrio   Nick Robinson
# 1      Nicholas Hoult     Josh Helman
# 2        Ansel Elgort    Miles Teller
# 3         Adam Driver    Daisy Ridley
# 4  Michelle Rodriguez  Dwayne Johnson

# %%
#change column names to more usefull not just 0-4
#this on e for cast

cast_names_split.columns = ['cast1','cast2','cast3','cast4','cast5']
cast_names_split.head()
# Out:
#               cast1                cast2             cast3  \
# 0       Chris Pratt  Bryce Dallas Howard       Irrfan Khan
# 1         Tom Hardy      Charlize Theron  Hugh Keays-Byrne
# 2  Shailene Woodley           Theo James      Kate Winslet
# 3     Harrison Ford          Mark Hamill     Carrie Fisher
# 4        Vin Diesel          Paul Walker     Jason Statham
#
#                 cast4           cast5
# 0   Vincent D'Onofrio   Nick Robinson
# 1      Nicholas Hoult     Josh Helman
# 2        Ansel Elgort    Miles Teller
# 3         Adam Driver    Daisy Ridley
# 4  Michelle Rodriguez  Dwayne Johnson

# %%
cast_member_list = cast_names_split.values.tolist()
print(cast_member_list)
# Out:
# [['Chris Pratt', 'Bryce Dallas Howard', 'Irrfan Khan', "Vincent D'Onofrio", 'Nick Robinson'], ['Tom Hardy', 'Charlize Theron', 'Hugh Keays-Byrne', 'Nicholas Hoult', 'Josh Helman'], ['Shailene Woodley', 'Theo James', 'Kate Winslet', 'Ansel Elgort', 'Miles Teller'], ['Harrison Ford', 'Mark Hamill', 'Carrie Fisher', 'Adam Driver', 'Daisy Ridley'], ['Vin Diesel', 'Paul Walker', 'Jason Statham', 'Michelle Rodriguez', 'Dwayne Johnson'], ['Leonardo DiCaprio', 'Tom Hardy', 'Will Poulter', 'Domhnall Gleeson', 'Paul Anderson'], ['Arnold Schwarzenegger', 'Jason Clarke', 'Emilia Clarke', 'Jai Courtney', 'J.K. Simmons'], ['Matt Damon', 'Jessica Chastain', 'Kristen Wiig', 'Jeff Daniels', 'Michael Pe\xc3\x83\xc2\xb1a'], ['Sandra Bullock', 'Jon Hamm', 'Michael Keaton', 'Allison Janney', 'Steve Coogan'], ['Amy Poehler', 'Phyllis Smith', 'Richard Kind', 'Bill Hader', 'Lewis Black'], ['Daniel Craig', 'Christoph Waltz', 'L\xc3\x83\xc2\xa9a Seydoux', 'Ralph Fiennes', 'Monica Bellucci'], ['Mila Kunis', 'Channing Tatum', 'Sean Bean', 'Eddie Redmayne', 'Douglas Booth'], ['Domhnall Gleeson', 'Alicia Vikander', 'Oscar Isaac', 'Sonoya Mizuno', 'Corey Johnson'], ['Adam Sandler', 'Michelle Monaghan', 'Peter Dinklage', 'Josh Gad', 'Kevin James'], ['Robert Downey Jr.', 'Chris Hemsworth', 'Mark Ruffalo', 'Chris Evans', 'Scarlett Johansson'], ['Samuel L. Jackson', 'Kurt Russell', 'Jennifer Jason Leigh', 'Walton Goggins', 'Demi\xc3\x83\xc2\xa1n Bichir'], ['Liam Neeson', 'Forest Whitaker', 'Maggie Grace', 'Famke Janssen', 'Dougray Scott'], ['Paul Rudd', 'Michael Douglas', 'Evangeline Lilly', 'Corey Stoll', 'Bobby Cannavale'], ['Lily James', 'Cate Blanchett', 'Richard Madden', 'Helena Bonham Carter', 'Holliday Grainger'], ['Jennifer Lawrence', 'Josh Hutcherson', 'Liam Hemsworth', 'Woody Harrelson', 'Elizabeth Banks'], ['Britt Robertson', 'George Clooney', 'Raffey Cassidy', 'Thomas Robinson', 'Hugh Laurie'], ['Jake Gyllenhaal', 'Rachel McAdams', 'Forest Whitaker', 'Oona Laurence', '50 Cent'], ['Dwayne Johnson', 'Alexandra Daddario', 'Carla Gugino', 'Ioan Gruffudd', 'Archie Panjabi'], ['Dakota Johnson', 'Jamie Dornan', 'Jennifer Ehle', 'Eloise Mumford', 'Victor Rasuk'], ['Christian Bale', 'Steve Carell', 'Ryan Gosling', 'Brad Pitt', 'Melissa Leo'], ['Tom Cruise', 'Jeremy Renner', 'Simon Pegg', 'Rebecca Ferguson', 'Ving Rhames'], ['Mark Wahlberg', 'Seth MacFarlane', 'Amanda Seyfried', 'Jessica Barth', 'Giovanni Ribisi'], ['Taron Egerton', 'Colin Firth', 'Samuel L. Jackson', 'Michael Caine', 'Mark Strong'], ['Mark Ruffalo', 'Michael Keaton', 'Rachel McAdams', 'Liev Schreiber', 'John Slattery'], ["Dylan O'Brien", 'Kaya Scodelario', 'Thomas Brodie-Sangster', 'Giancarlo Esposito', 'Aidan Gillen'], ['Ian McKellen', 'Milo Parker', 'Laura Linney', 'Hattie Morahan', 'Patrick Kennedy'], ['Sharlto Copley', 'Dev Patel', 'Ninja', 'Yolandi Visser', 'Jose Pablo Cantillo'], ['Anna Kendrick', 'Rebel Wilson', 'Hailee Steinfeld', 'Brittany Snow', 'Skylar Astin'], ['Tom Hanks', 'Mark Rylance', 'Amy Ryan', 'Alan Alda', 'Sebastian Koch'], ['Jack Black', 'Dylan Minnette', 'Odeya Rush', 'Amy Ryan', 'Jillian Bell'], ['Brie Larson', 'Jacob Tremblay', 'Joan Allen', 'Sean Bridgers', 'William H. Macy'], ['Abbie Cornish', 'Jeffrey Dean Morgan', 'Colin Farrell', 'Anthony Hopkins', 'Marley Shelton'], ['Raymond Ochoa', 'Jack Bright', 'Jeffrey Wright', 'Frances McDormand', 'Maleah Nipay-Padilla'], ['Liam Neeson', 'Ed Harris', 'Joel Kinnaman', 'Boyd Holbrook', 'Bruce McGill'], ['Saoirse Ronan', 'Domhnall Gleeson', 'Emory Cohen', 'Emily Bett Rickards', "Eileen O'Higgins"], ["O'Shea Jackson Jr.", 'Corey Hawkins', 'Jason Mitchell', 'Neil Brown Jr.', 'Aldis Hodge'], ['Vin Diesel', 'Rose Leslie', 'Michael Caine', 'Elijah Wood', '\xc3\x83\xe2\x80\x9clafur Darri \xc3\x83\xe2\x80\x9clafsson'], ['Michael Fassbender', 'Kate Winslet', 'Seth Rogen', 'Katherine Waterston', 'Jeff Daniels'], ['Henry Cavill', 'Armie Hammer', 'Alicia Vikander', 'Elizabeth Debicki', 'Luca Calvani'], ['Blake Lively', 'Michiel Huisman ...

# %%
flat_cast_list = [num for elem in cast_member_list for num in elem]
print (flat_cast_list)
# Out:
# ['Chris Pratt', 'Bryce Dallas Howard', 'Irrfan Khan', "Vincent D'Onofrio", 'Nick Robinson', 'Tom Hardy', 'Charlize Theron', 'Hugh Keays-Byrne', 'Nicholas Hoult', 'Josh Helman', 'Shailene Woodley', 'Theo James', 'Kate Winslet', 'Ansel Elgort', 'Miles Teller', 'Harrison Ford', 'Mark Hamill', 'Carrie Fisher', 'Adam Driver', 'Daisy Ridley', 'Vin Diesel', 'Paul Walker', 'Jason Statham', 'Michelle Rodriguez', 'Dwayne Johnson', 'Leonardo DiCaprio', 'Tom Hardy', 'Will Poulter', 'Domhnall Gleeson', 'Paul Anderson', 'Arnold Schwarzenegger', 'Jason Clarke', 'Emilia Clarke', 'Jai Courtney', 'J.K. Simmons', 'Matt Damon', 'Jessica Chastain', 'Kristen Wiig', 'Jeff Daniels', 'Michael Pe\xc3\x83\xc2\xb1a', 'Sandra Bullock', 'Jon Hamm', 'Michael Keaton', 'Allison Janney', 'Steve Coogan', 'Amy Poehler', 'Phyllis Smith', 'Richard Kind', 'Bill Hader', 'Lewis Black', 'Daniel Craig', 'Christoph Waltz', 'L\xc3\x83\xc2\xa9a Seydoux', 'Ralph Fiennes', 'Monica Bellucci', 'Mila Kunis', 'Channing Tatum', 'Sean Bean', 'Eddie Redmayne', 'Douglas Booth', 'Domhnall Gleeson', 'Alicia Vikander', 'Oscar Isaac', 'Sonoya Mizuno', 'Corey Johnson', 'Adam Sandler', 'Michelle Monaghan', 'Peter Dinklage', 'Josh Gad', 'Kevin James', 'Robert Downey Jr.', 'Chris Hemsworth', 'Mark Ruffalo', 'Chris Evans', 'Scarlett Johansson', 'Samuel L. Jackson', 'Kurt Russell', 'Jennifer Jason Leigh', 'Walton Goggins', 'Demi\xc3\x83\xc2\xa1n Bichir', 'Liam Neeson', 'Forest Whitaker', 'Maggie Grace', 'Famke Janssen', 'Dougray Scott', 'Paul Rudd', 'Michael Douglas', 'Evangeline Lilly', 'Corey Stoll', 'Bobby Cannavale', 'Lily James', 'Cate Blanchett', 'Richard Madden', 'Helena Bonham Carter', 'Holliday Grainger', 'Jennifer Lawrence', 'Josh Hutcherson', 'Liam Hemsworth', 'Woody Harrelson', 'Elizabeth Banks', 'Britt Robertson', 'George Clooney', 'Raffey Cassidy', 'Thomas Robinson', 'Hugh Laurie', 'Jake Gyllenhaal', 'Rachel McAdams', 'Forest Whitaker', 'Oona Laurence', '50 Cent', 'Dwayne Johnson', 'Alexandra Daddario', 'Carla Gugino', 'Ioan Gruffudd', 'Archie Panjabi', 'Dakota Johnson', 'Jamie Dornan', 'Jennifer Ehle', 'Eloise Mumford', 'Victor Rasuk', 'Christian Bale', 'Steve Carell', 'Ryan Gosling', 'Brad Pitt', 'Melissa Leo', 'Tom Cruise', 'Jeremy Renner', 'Simon Pegg', 'Rebecca Ferguson', 'Ving Rhames', 'Mark Wahlberg', 'Seth MacFarlane', 'Amanda Seyfried', 'Jessica Barth', 'Giovanni Ribisi', 'Taron Egerton', 'Colin Firth', 'Samuel L. Jackson', 'Michael Caine', 'Mark Strong', 'Mark Ruffalo', 'Michael Keaton', 'Rachel McAdams', 'Liev Schreiber', 'John Slattery', "Dylan O'Brien", 'Kaya Scodelario', 'Thomas Brodie-Sangster', 'Giancarlo Esposito', 'Aidan Gillen', 'Ian McKellen', 'Milo Parker', 'Laura Linney', 'Hattie Morahan', 'Patrick Kennedy', 'Sharlto Copley', 'Dev Patel', 'Ninja', 'Yolandi Visser', 'Jose Pablo Cantillo', 'Anna Kendrick', 'Rebel Wilson', 'Hailee Steinfeld', 'Brittany Snow', 'Skylar Astin', 'Tom Hanks', 'Mark Rylance', 'Amy Ryan', 'Alan Alda', 'Sebastian Koch', 'Jack Black', 'Dylan Minnette', 'Odeya Rush', 'Amy Ryan', 'Jillian Bell', 'Brie Larson', 'Jacob Tremblay', 'Joan Allen', 'Sean Bridgers', 'William H. Macy', 'Abbie Cornish', 'Jeffrey Dean Morgan', 'Colin Farrell', 'Anthony Hopkins', 'Marley Shelton', 'Raymond Ochoa', 'Jack Bright', 'Jeffrey Wright', 'Frances McDormand', 'Maleah Nipay-Padilla', 'Liam Neeson', 'Ed Harris', 'Joel Kinnaman', 'Boyd Holbrook', 'Bruce McGill', 'Saoirse Ronan', 'Domhnall Gleeson', 'Emory Cohen', 'Emily Bett Rickards', "Eileen O'Higgins", "O'Shea Jackson Jr.", 'Corey Hawkins', 'Jason Mitchell', 'Neil Brown Jr.', 'Aldis Hodge', 'Vin Diesel', 'Rose Leslie', 'Michael Caine', 'Elijah Wood', '\xc3\x83\xe2\x80\x9clafur Darri \xc3\x83\xe2\x80\x9clafsson', 'Michael Fassbender', 'Kate Winslet', 'Seth Rogen', 'Katherine Waterston', 'Jeff Daniels', 'Henry Cavill', 'Armie Hammer', 'Alicia Vikander', 'Elizabeth Debicki', 'Luca Calvani', 'Blake Lively', 'Michiel Huisman', 'Harrison Ford', 'Ellen Burstyn', 'Kathy Baker', 'Sharlto Copley', 'Haley Bennett', 'D ...

# %%
len(flat_cast_list)
# Out:
# 54330

# %%
Counter(flat_cast_list)
# Out:
# Counter({nan: 76,
#          'Takumi Yamazaki': 1,
#          'Alex Zahara': 2,
#          'Claude Rains': 1,
#          'Felissa Rose': 1,
#          'Omid Djalili': 4,
#          'Jacki Weaver': 9,
#          'Vonetta McGee': 2,
#          'Avis Bunnage': 1,
#          'Juan Carlos Serr\xc3\x83\xc2\xa1n': 1,
#          'Tom Noonan': 3,
#          'Aaron Spann': 1,
#          'James Le Gros': 8,
#          'David Fox': 3,
#          'Fred Ewanuick': 1,
#          'Sean Maher': 1,
#          'Yang Dong-geun': 1,
#          'Adam Fristoe': 1,
#          'Mary-Charles Jones': 1,
#          'Julie Kavner': 3,
#          'Maddi Black': 1,
#          'Ethan Embry': 12,
#          'Lymari Nadal': 1,
#          'Eamon Farren': 2,
#          'Zach Cohen': 1,
#          'Tonya Kay': 1,
#          'John Putch': 1,
#          'Gaelan Connell': 1,
#          'Barbara Luddy': 1,
#          "Jermaine 'Huggy' Hopkins": 1,
#          'Robert Evans': 1,
#          'Ed Quinn': 4,
#          'Ashley Bashy Thomas': 3,
#          'Mark Hadlow': 1,
#          'Jonah Hill': 21,
#          'Sanath Menon': 1,
#          'Gabrielle Rose': 3,
#          'Ken Lerner': 1,
#          'Peter Boyden': 1,
#          'Busta Rhymes': 5,
#          'Anndi McAfee': 5,
#          'Salomon Perel': 1,
#          'Mike Downey': 1,
#          'Riley Griffiths': 1,
#          'Simon Gleeson': 1,
#          'Nicole Alonso': 1,
#          'Marcel Iure\xc3\x88\xe2\x84\xa2': 5,
#          'Rafi Gavron': 2,
#          'Pam Cooke': 1,
#          'Bobby Campo': 1,
#          'Sisca Jessica': 1,
#          'Robyn Rikoon': 1,
#          'Sidharth Malhotra': 2,
#          'J\xc3\x83\xc2\xb3hann G. J\xc3\x83\xc2\xb3hannsson': 1,
#          'Kate Reid': 5,
#          'Anne Bancroft': 15,
#          'Amanda Grace Cooper': 1,
#          'Geraldine James': 6,
#          'Jo Yang': 1,
#          'Annika Marks': 2,
#          'Sean Johnson': 1,
#          'James Patrick Stuart': 1,
#          'Peter van Eyck': 1,
#          'Margaret Whiting': 1,
#          'Anna Paquin': 15,
#          'Ava Gardner': 5,
#          'Sigmund Vik': 1,
#          'Samantha Morton': 15,
#          'Simona Maicanescu': 1,
#          'Rajia Baroudi': 1,
#          'James Caan': 23,
#          'Edo Van Breemen': 1,
#          'Henry Brown': 1,
#          'Mads Koudal': 1,
#          'Tyra Banks': 1,
#          'Jeananne Goossen': 2,
#          'Razane Jammal': 1,
#          'Clyde Lewis': 1,
#          'Mackenzie Astin': 4,
#          'David Spade': 14,
#          'Jeremy Cooper': 1,
#          'Savely Kramarov': 1,
#          'Charlotte Prior': 1,
#          'Mandy-Rae Cruikshank': 1,
#          'Abbey DiGregorio': 1,
#          'Muqbal Al Kazemi': 1,
#          'Tom Gilroy': 1,
#          'Kayren Butler': 1,
#          'Jason Lewis': 2,
#          'Dan Creed': 1,
#          'Shirley Eaton': 2,
#          'Robin Walsh': 1,
#          'Carolina G\xc3\x83\xc2\xb3mez': 1,
#          'Christopher Jordan Wallace': 1,
#          'Jennifer Pudavick': 1,
#          'Nick Faltas': 1,
#          'Eriq La Salle': 1,
#          'Anthony Sneed': 1,
#          'Christina Milian': 6,
#          'Malala Yousafzai': 1,
#          'Carson Underwood': 1,
#          '\xc3\x83\xe2\x80\x9cscar Jaenada': 2,
#          'Emma Stone': 16,
#          'Megumi Odaka': 1,
#          'Taliesin Jaffe': 1,
#          'Logan Huffman': 2,
#          'Paul McGillion': 4,
#          'Percy Daggs III': 1,
#          'Kelle Cantwell': 1,
#          'Nora McMenamy': 1,
#          'Pauline Moran': 1,
#          'Ingvar Eggert Sigur\xc3\x83\xc2\xb0sson': 2,
#          'Marley Shelton': 8,
#          'Valin Shinyei': 1,
#          'Allen Iverson': 1,
#          'Ken Murton': 1,
#          'Laleh Pourkarim': 1,
#          'Ambyr Childers': 4,
#          'Tony Ganios': 3,
#          'Sam Riegel': 1,
#          'Margo Prey': 1,
#          'Coco Jones': 1,
#          'Chief Dan George': 2,
#          'Andrew Caldwell': 2,
#          'Leslie Carlson': 2,
#          'Kevin Chamberlin': 2,
#          'Germaine De Leon': 1,
#          'Summer Bellessa': 1,
#          'Kevin Gage': 5,
#          'Peter Donat': 2,
#          'Russell Sams': 1,
#          'Sophie Cook': 1,
#          'Wendy Raquel Robinson': 2,
#          'Mathilde Seigner': 2,
#          'Graham Phillips': 3,
#          'Erin Daniels': 2,
#          'Maurice Roeves': 2,
#          'Katey Sagal': 5,
#          'David Zayas': 2,
#          'Timothy E. Day': 1,
#          'Mary Kay Place': 8,
#          'Madison Desjarlais': 1,
#          'John Terry': 3,
#          'Christopher Martin': 1,
#          'Darla Biccum': 1,
#          'Riz Ahmed': 8,
#          'Dean Cameron': 3,
#          'Michael Winslow': 7,
#          'Ian Patrick Williams': 1,
#          'John Friedrich': 1,
#          'Michael De Mesa': 1,
#          'Nigel Green': 4,
#          'Carly Pope': 4,
#          'Rhys Ifans': 21,
#          'J. A. Preston': 1,
#          'Cassidy Ladden': 1,
#          '\xc3\x83ron Dim\xc3\x83\xc2\xa9ny': 1,
#          'Richard Crenna': 9,
#          'Jerry Daugirda': 1,
#          'Deborah Odell': 1,
#          'Rebecca Creskoff': 1,
#          'Glen Barry': 1,
#          'Jason Burkett': 1,
#          'Scott Hazell': 1,
#          'Andrew Cassese': 1,
#          'Will Hutchins': 1,
#          'Daren Kagasoff': 1,
#          'Jessalyn Gilsig': 2,
#          'Mason Gamble': 2,
#          'Wendel Calvert': 1,
#          'Gordon Howard': 1,
#          'Philippe Krhajac': 1,
#          'Adam Harrington': 2,
#          'Alfred Lynch': 2,
#          'Sara Canning': 1,
#          'Michael Weston': 3,
#          'Michel Simon': 1,
#          'Harvey Stephens': 1,
#          'Janet Montgomery': 3,
#          'Christopher Walken': 46,
#          'Sam Scarber': 1,
#          'John Ross Bowie': 1,
#          'Edouard Montoute': 1,
#          'Clint Howard': 7,
#          'Toby Froud': 1,
#          'Burgess Meredith': 12,
#          'Fritz Wepper': 1,
#          'Dyllan Christopher': 1,
#          'Billy Asher': 1,
#          'Fardeen Khan': 1,
#          'Shawn Yue': 3,
#          'Julia Voth': 1,
#          'Tom Towles': 2,
#          'Scott Harders': 1,
#          'Ezra Godden': 1,
#          'Brendon Baerg': 1,
#          'Valorie Armstrong': 1,
#          'Arturo Venegas': 1,
#          'Kelly Macdonald': 10,
#          'Yoko Ono': 1,
#          'Kai Wulff': 1,
#          'Naomi Campbell': 1,
#          'Gwendoline Yeo': 3,
#          'Akiko Wakabayashi': 2,
#          'Andrew Schofield': 1,
#          'Karan Soni': 1,
#          'Derek Jacobi': 7,
#          'Tina Lifford': 2,
#          'Heather Langenkamp': 5,
#          'Amila Terzimehic': 1,
#          'Yaphet Kotto': 8,
#          'Ry\xc3\x85hei Kimura': 1,
#          'Sarah Brightman': 1,
#          'Freda Foh Shen': 1,
#          'Jack McMullen': 1,
#          'Dave Levine': 1,
#          'Hidetaka Yoshioka': 1,
#          'Cole Konis': 1,
#          'Billie Whitelaw': 4,
#          'Michelle Bauer': 1,
#          'Anne De Salvo': 1,
#          'Stone Gossard': 1,
#          'Hafsia Herzi': 1,
#          'Sandrine Bonnaire': 1,
#          'Marc Strange': 1,
#          'Nicole de Boer': 2,
#          'McKee Anderson': 1,
#          'Monica Potter': 5,
#          'Andreas Leupold': 1,
#          'Caroline Sunshine': 1,
#          'Lena Headey': 17,
#          'Ross Kidder': 1,
#          'Adam Coutts': 1,
#          'Abigail Schrader': 1,
#          'Emmy Rossum': 9,
#          'Dolores del R\xc3\x83\xc2\xado': 2,
#          'Frank Frankson': 1,
#          'Andrew Prine': 4,
#          'Joan Greenwood': 2,
#          'Roberto \xc3\x83lamo': 1,
#          'Sianoa Smit-McPhee': 1,
#          'Gerard Jordan': 1,
#          'Caroline Langrishe': 1,
#          'Julia Pott': 1,
#          'Tomo Mili\xc3\x84evi\xc3\x84\xe2\x80\xa1': 1,
#          'Pete Postlethwaite': 16,
#          'Chris Klein': 14,
#          'Fran\xc3\x83\xc2\xa7oise Chich\xc3\x83\xc2\xa9ry': 1,
#          'Ramon Tikaram': 1,
#          'Chandler Riggs': 1,
#          'Brigitte Nielsen': 4,
#          'Stewart Granger': 1,
#          'Suzanne Flon': 2,
#          'Thomas Galasso': 1,
#          'Dzana Pinjo': 1,
#          'Tawny Kitaen': 6,
#          'Fred Ward': 20,
#          'Karen Abercrombie': 1,
#          'Michael Welch': 8,
#          'Cahit \xc3\x83\xe2\x80\x93lmez': 1,
#          'Emily Watson': 19,
#          'Gr\xc3\x83\xc2\xa9goire Aslan': 1,
#          'Laura San Giacomo': 2,
#          'Raini Rodriguez': 3,
#          'J\xc3\x83\xc2\xbcrgen Prochnow': 8,
#          'Yvonne Monlaur': 1,
#          'Nicholas Woodeson': 2,
#          "Simon O'Connor": 1,
#          'Luther Adler': 1,
#          'Woody Harrelson': 43,
#          'Freya Tingley': 1,
#          'Donald Rumsfeld': 1,
#          'James McCaffrey': 4,
#          'Tom Wu': 3,
#          'Dexter Fletcher': 2,
#          'Lucky Johnson': 1,
#          'Toor Pekai Yousafzai': 1,
#          'Nelsan Ellis': 4,
#          'Kevin Smith Kirkwood': 1,
#          'Jesse L. Martin': 1,
#          'Jon Bernthal': 6,
#          'Mie Hama': 2,
#          'David Eigenberg': 1,
#          'Lauren Vera': 1,
#          'Mike Judge': 1,
#          'David Paul': 1,
#          'Will Sasso': 5,
#          'Nia Vardalos': 4,
#          'David Schlachtenhaufen': 1,
#          'Vernon Wells': 3,
#          'Edward Norton': 23,
#          'Randy Steinmeyer': 1,
#          'Cynthia Francesconi': 1,
#          'Peter Krause': 3,
#          'Niki Harris': 1,
#          'Bill Hader': 16,
#          'Demi Moore': 29,
#          'Ben Mendelsohn': 9,
#          'Michael Constantine': 3,
#          'N!xau': 2,
#          'Aidan Turner': 1,
#          'Stephen Mendel': 2,
#          'Touriya Haoud': 1,
#          'Dennis Weaver': 1,
#          'Paul Linke': 1,
#          'Alan Wilder': 1,
#          'Chloe Hunter': 1,
#          'Lacey Chabert': 9,
#          'Katherine Waterston': 6,
#          'Tyler James Williams': 3,
#          'Philip Quast': 1,
#          'Luke Baines': 1,
#          'Michael Chen': 1,
#          'Tabor Helton': 1,
#          'Katharine Towne': 1,
#          'Ryan McCluskey': 2,
#          'Timothy J. Cox': 1,
#          'Scott Thompson': 1,
#          'Jean-Claude Van Damme': 40,
#          'Rob Freeman': 1,
#          'Christopher Britton': 1,
#          'Jos\xc3\x83\xc2\xa9 Lewgoy': 2,
#          'Danielle Chuchran': 5,
#          'Louis Eppolito': 1,
#          'Carter Hastings': 1,
#          'Zo\xc3\x83\xc2\xab Belkin': 1,
#          'Lori Heuring': 3,
#          'Kelly Adams': 1,
#          'Florence Pernel': 1,
#          'Christopher Gaze': 1,
#          'Richard G. Wilkinson': 1,
#          'Bill Amend': 1,
#          'Alistair Abell': 2,
#          'David Arkin': 2,
#          "Olivia d'Abo": 9,
#          'Jay R. Ferguson': 2,
#          'Olivier Gourmet': 7,
#          'Joe Dempsie': 2,
#          'Catherine Bell': 6,
#          'Jayne Brook': 1,
#          'Andrea Bogart': 1,
#          'Marco Confortola': 1,
#          'Desi Lydic': 2,
#          "Grant O'Connell": 1,
#          'Laura Cayouette': 3,
#          'Patrick Casey': 1,
#          'Breckin Meyer': 10,
#          'Michelle Harrison': 1,
#          'Brontis Jodorowsky': 1,
#          'Torrey DeVitto': 2,
#          'Chris Stafford': 1,
#          'Arnold Vosloo': 9,
#          'Jeff Bridges': 39,
#          'Frankie Man': 1,
#          'Emma Catherwood': 1,
#          'Tom Everett': 1,
#          'Helen Shaver': 4,
#          'Dwaine Stevenson': 1,
#          'Devin Ratray': 1,
#          'Jimmy Somerville': 1,
#          'Billy Burke': 10,
#          'Guy Clark': 1,
#          'Amy Jo Johnson': 2,
#          'Josie Ho': 2,
#          'Jeffrey Hunter': 2,
#          'Casey Stoner': 2,
#          'George Shevtsov': 1,
#          'Sandi Dragoi': 1,
#          'Mathew Wilkinson': 1,
#          'Dwyane Wade': 1,
#          'Stephen Jennings': 1,
#          'Matt Dillon': 24,
#          'M\xc3\x83\xc2\xada Maestro': 6,
#          'Mary Lynn Rajskub': 2,
#          'Nina Simone': 1,
#          'Jeffrey Zekele': 1,
#          'Alisha Newton': 1,
#          'Ingrid Bergman': 2,
#          'Linda Harrison': 1,
#          'Michael Riley': 2,
#          'Gary Oldman': 36,
#          'Anna Chancellor': 2,
#          'Miranda Otto': 9,
#          'Fernando Lara': 1,
#          'Matthias Schoenaerts': 8,
#          'Danny Corkill': 1,
#          'Edie Martin': 1,
#          'Jennifer Schwalbach Smith': 1,
#          'Amy Morton': 1,
#          'James Lance': 2,
#          'Courtney Ford': 1,
#          'Hillary Clinton': 1,
#          'Iqbal Theba': 1,
#          'Elham Sharifi': 1,
#          'Linda Hamilton': 10,
#          'Seth MacFarlane': 8,
#          'Matthew Laurance': 1,
#          'Alex Reid': 2,
#          'Fann Wong': 1,
#          'Brandon Call': 1,
#          'Richard Stanley': 1,
#          'Brice Fournier': 1,
#          'G. D. Spradlin': 1,
#          'L.C. Holt': 1,
#          'Iftach Ophir': 1,
#          'Richard Schiff': 2,
#          'Burt Ward': 1,
#          'Dan-qing Chen': 1,
#          'Glenn Gyorffy': 1,
#          'Gina Holden': 5,
#          'Jim King': 1,
#          'Katy Jurado': 4,
#          'Alain Prost': 1,
#          'Shannon Beckner': 1,
#          'Natalie Gregory': 1,
#          'Danny McBride': 11,
#          'Rinko Kikuchi': 4,
#          'Jaime Tirelli': 2,
#          'Alfie Owen': 1,
#          'Lee Cormie': 1,
#          'Jason Hall': 1,
#          'Ricki Lake': 3,
#          'Liam Hemsworth': 11,
#          'Elizabeth Hunter': 1,
#          'Stanley Kubrick': 1,
#          'Booboo Stewart': 6,
#          'Tracy Camilla Johns': 1,
#          'Patricia Hayes': 1,
#          'Yolanda Ross': 1,
#          'Matt Mullins': 1,
#          'Tim Jenison': 1,
#          'Hilary Greer': 1,
#          'Hannah Tointon': 1,
#          'Nancy Morgan': 1,
#          'Lulu': 1,
#          'Wyatt Russell': 2,
#          'Fionnula Flanagan': 5,
#          'Luana Anders': 1,
#          'Kylie Minogue': 4,
#          'Josh Charles': 8,
#          'Christopher Evan Welch': 1,
#          'Charlotte Riley': 2,
#          'Nicholas Lea': 1,
#          'Jane Akre': 1,
#          'Claude Brasseur': 2,
#          'Trevor Matthews': 1,
#          'Nathaniel Parker': 6,
#          'James Spader': 15,
#          'Gianni Franco': 1,
#          'India Salvor Menuez': 1,
#          'John Mulaney': 2,
#          'Victoria Pratt': 2,
#          'Matt Bellefleur': 1,
#          'Gregg Sulkin': 2,
#          'Susan Burke': 1,
#          'Kate Ashfield': 6,
#          'Bryan Clark': 1,
#          'Lisa Eichhorn': 3,
#          'Luis \xc3\x83valos': 1,
#          'Brittany Underwood': 2,
#          'Lisa Ruth Andreozzi': 1,
#          'Ted Wass': 1,
#          'H\xc3\x83\xc2\xa9l\xc3\x83\xc2\xa8ne Vincent': 4,
#          'Nikos Mavrakis': 1,
#          'Bailey Spry': 1,
#          'Katie Sarife': 1,
#          'Matthew R. Anderson': 1,
#          'Richard Lynch': 7,
#          'Dean Cain': 10,
#          'Richard Karn': 1,
#          'Danielle Proulx': 1,
#          'John Fell Ryan': 1,
#          'Elliott Gould': 5,
#          'Austin Basis': 2,
#          'Britt Leach': 1,
#          'Tara Strong': 15,
#          'David Chung': 1,
#          'Randeep Hooda': 4,
#          'Bill Engvall': 1,
#          'Torkel Petersson': 1,
#          'Celina Jade': 2,
#          'Lara Cox': 1,
#          'Adam Deacon': 6,
#          "Carmen Dell'Orefice": 1,
#          'Adam Cronheim': 1,
#          'Russell G. Jones': 1,
#          'Kristen Connolly': 4,
#          'Ariel Levy': 2,
#          'Yuri Pleskun': 1,
#          'Joris Jarsky': 1,
#          'Greg Bryk': 3,
#          'Michelle Pierce': 1,
#          'Jenn Proske': 1,
#          'Anderson Silva': 1,
#          'Ding Laam': 1,
#          'Tshepo Maseko': 1,
#          'Bibi Besch': 1,
#          'Elina L\xc3\x83\xc2\xb6wensohn': 2,
#          'Timothy Davis': 1,
#          'Tommy Redmond Hicks': 1,
#          'Janet Ulrich Brooks': 1,
#          'Ali Al Ameri': 1,
#          'Zachary Soetenga': 1,
#          'Abigail Breslin': 18,
#          'Martin Starr': 9,
#          'Adam Sessa': 1,
#          'Vincenzo Salemme': 1,
#          'Nate Corddry': 1,
#          'David Ajala': 1,
#          'Tsai Chin': 1,
#          'Gene Sprague': 1,
#          'Clifford Ba\xc3\x83\xc2\xb1agale': 1,
#          'Markus Persson': 1,
#          'Konstantin Khabenskiy': 1,
#          'Julia Bremermann': 1,
#          'Eric Allan Kramer': 2,
#          'Loni von Friedl': 1,
#          "Conan O'Brien": 2,
#          'Ario Bayu': 1,
#          'Timyra-Joi Beatty': 1,
#          'Yvette Yates': 1,
#          'George Buck Flower': 1,
#          'Eric Bogosian': 2,
#          'Glenn Close': 24,
#          'Michael Stefani': 1,
#          'Esm\xc3\x83\xc2\xa9 Bianco': 2,
#          'Maia Mitchell': 2,
#          'Peter Barton': 1,
#          'Ahn Sung-Ki': 2,
#          'Spencer Breslin': 9,
#          'Patrice Martinez': 1,
#          'Brad Davis': 1,
#          'Lexi Ainsworth': 2,
#          'Takao Osawa': 1,
#          'Charlie Barnett': 2,
#          'Denise Richards': 14,
#          'Catherine Chevallier': 1,
#          'Zsolt Nagy': 1,
#          'Gail Porter': 1,
#          'Jay Klaitz': 2,
#          'Aishwarya Rai Bachchan': 8,
#          'Jennifer Echols': 1,
#          'Ken Stott': 8,
#          'Owen Teale': 1,
#          'Paolo Stoppa': 1,
#          'Tatyana Ali': 2,
#          'Sam Elliott': 16,
#          'Tego Calder\xc3\x83\xc2\xb3n': 1,
#          'Paul Campbell': 2,
#          'Candace Cameron Bure': 1,
#          'Johnny Lewis': 2,
#          'T\xc3\x83\xc2\xa9a Leoni': 11,
#          'Ramzy Bedia': 4,
#          'Jamie Foxx': 23,
#          'Ian Anderson': 1,
#          'Howie Lai': 1,
#          'Jim Chanos': 1,
#          'Cy Carter': 1,
#          'Emma Roberts': 18,
#          'Al Pacino': 41,
#          'Richard Jaeckel': 5,
#          'Jordan Todosey': 1,
#          'Richard Kiley': 1,
#          'Callan McAuliffe': 5,
#          'Alan Badel': 4,
#          'Aarti Mann': 2,
#          'Devid Striesow': 1,
#          'Uta Levka': 1,
#          'Jeremy Kemp': 2,
#          'Pepper LaBeija': 1,
#          'Anthony Lemke': 1,
#          'Emma Samms': 1,
#          'Gabriel Rush': 1,
#          'Roger Allam': 1,
#          'Danny Jacobs': 2,
#          'Ed Viesturs': 1,
#          'Claire Cordingley': 1,
#          'Vesa Vierikko': 1,
#          'Sarala': 1,
#          'Tim Perez': 1,
#          'Roxane Mesquida': 4,
#          'Kerry Armstrong': 1,
#          'Brad Roberge': 1,
#          'Roman Polanski': 1,
#          'Ryan Giggs': 1,
#          'Amanda Donohoe': 3,
#          'Brian Wimmer': 1,
#          'Johnny Lever': 1,
#          'Karen Holness': 1,
#          'Molly Tarlov': 1,
#          'Adrian Zmed': 1,
#          'Johan Urb': 1,
#          'Maaya Sakamoto': 1,
#          'Sarah Jayne Jensen': 1,
#          'Reggie Watts': 1,
#          '"Weird Al" Yankovic': 1,
#          "N'Bushe Wright": 2,
#          'Paul A. Partain': 1,
#          'Jennie Linden': 1,
#          'Nicole Beharie': 2,
#          'Jon Roberts': 1,
#          'Jill Townsend': 1,
#          'Stephen McCole': 2,
#          'Gabriel Bateman': 1,
#          'Clifton Collins, Jr.': 12,
#          'Ming-Na Wen': 5,
#          'Keith Carradine': 7,
#          'Julian Barratt': 2,
#          'Freddie Jones': 5,
#          'Chen Bolin': 1,
#          'Steve Caballero': 2,
#          'Robert Gwilym': 1,
#          'Joan Allen': 16,
#          'Lyle Lovett': 2,
#          'Robin Riker': 3,
#          'Dave Legeno': 2,
#          'Rich McDonald': 1,
#          'Natalia Avelon': 1,
#          'Nick Robinson': 5,
#          'Stomy Bugsy': 1,
#          'Craig Archibald': 1,
#          'Cliff Gorman': 1,
#          'Kimberly Elise': 7,
#          'Kate Miles': 1,
#          'Rolf Lassg\xc3\x83\xc2\xa5rd': 2,
#          'Damon Wayans Jr.': 3,
#          'Kay Medford': 1,
#          'Jennifer Nyholm': 1,
#          'Steffany Huckaby': 1,
#          'Charlie Watts': 2,
#          'David Verdaguer': 1,
#          'James Madio': 3,
#          'Ruta Gedmintas': 1,
#          'Georgina Chapman': 1,
#          'Ranveer Singh': 2,
#          'Damon Martin': 1,
#          'Kate Trotter': 1,
#          'Maurice Smith': 1,
#          'Lachy Hulme': 2,
#          'Jay Leno': 1,
#          'Dove Cameron': 4,
#          'Jeroen Krabb\xc3\x83\xc2\xa9': 8,
#          'Gail DeFaria': 1,
#          'Brett Goldstein': 1,
#          'Richard Harmon': 3,
#          'Barbara Parkins': 1,
#          'Anthony Higgins': 3,
#          'Bachchan Pachera': 1,
#          'Cleopatra Coleman': 1,
#          'Hutch Dano': 1,
#          'Gina Marie May': 1,
#          'Jan Machulski': 1,
#          'Brian Skala': 1,
#          'Morgan West': 1,
#          'Simon Cotton': 1,
#          'Natasha Hovey': 1,
#          'Andrew Howard': 2,
#          'Matt Doran': 1,
#          'Parker Goris': 1,
#          'Svetlana Druzhinina': 1,
#          'Jennifer Clay': 1,
#          'Norman Baert': 1,
#          'Colin Farrell': 35,
#          'Freddie Stroma': 3,
#          'Michael Jackson': 5,
#          'Donald Hodson': 1,
#          'Tao Okamoto': 1,
#          "Tommy 'Tiny' Lister": 3,
#          'Carrie Crawford': 1,
#          'Kristopher Logan': 1,
#          'Tami Erin': 1,
#          'Emma Fitzpatrick': 3,
#          'William Sanderson': 2,
#          'Richard Lewis': 2,
#          'Harve Presnell': 1,
#          'Brian Wagner': 1,
#          'Pamela Binns': 1,
#          'Marshall Bell': 5,
#          'Melody Anderson': 3,
#          'Ty Burrell': 9,
#          'Corinna Tsopei': 1,
#          'Andy Merrill': 1,
#          'Kerry Washington': 15,
#          'Bella Heathcote': 3,
#          'Thelma Ritter': 2,
#          'John Osborne': 1,
#          "Chris O'Neill": 1,
#          'Deon Richmond': 1,
#          'Barry Miller': 3,
#          'Marianne S\xc3\x83\xc2\xa4gebrecht': 3,
#          'Anja Savcic': 2,
#          'J.G. Hertzler': 1,
#          'D.B. Woodside': 1,
#          'Giovonnie Samuels': 1,
#          'Jenny Seagrove': 1,
#          'Josie Maran': 1,
#          'Yvonne Clech': 1,
#          'Roschdy Zem': 5,
#          'Jay Brazeau': 4,
#          'Rick Cramer': 2,
#          'Chad Michael Murray': 8,
#          'Enzo Cilenti': 2,
#          'Vidal Sancho': 1,
#          'Thomas Orange': 1,
#          'Victor Garber': 10,
#          'Aur\xc3\x83\xc2\xa9lien Recoing': 1,
#          'Gideon Shemer': 1,
#          'Ashley Springer': 1,
#          'Su Cruickshank': 1,
#          'Beverly Todd': 3,
#          'Norah Jones': 1,
#          'Shep Gordon': 1,
#          'Frances Bay': 1,
#          'Helmut Qualtinger': 1,
#          'Brian Markinson': 2,
#          'Gillian Jacobs': 7,
#          'Val Kilmer': 39,
#          'Jack Creley': 1,
#          'Nicki Aycox': 2,
#          'Wesley Snipes': 33,
#          'Steve Jordan': 2,
#          'Mark Doherty': 1,
#          'Angus MacLane': 1,
#          'Katie Holmes': 19,
#          'Cody Hackman': 1,
#          'Ray McKinnon': 1,
#          'Harley Bird': 1,
#          'Douglas Fairbanks Jr.': 1,
#          'Kate Butler': 1,
#          'Nicholas Turturro': 1,
#          'Richard Felix': 2,
#          'James Arnold': 1,
#          'Nicky Whelan': 3,
#          'Sam Neill': 28,
#          'Emma Fuhrmann': 2,
#          'Ellen Barkin': 17,
#          'Maria Thayer': 1,
#          'Nicholas Bateman': 1,
#          'Fiona Lewis': 1,
#          'Maggie McOmie': 1,
#          'Enrique Castillo': 1,
#          'Debra Feuer': 1,
#          'Aryana Engineer': 1,
#          'Gattlin Griffith': 3,
#          'Connie Danese': 1,
#          'Justin Arnold': 1,
#          'Jenna Jameson': 2,
#          'Hartmut Becker': 1,
#          'Teresa Wright': 1,
#          'Margaret Rutherford': 3,
#          'Braam Greyling': 1,
#          'Gabe Nevins': 1,
#          'Laura Harris': 3,
#          'Aya Hirayama': 1,
#          'Zabou Breitman': 2,
#          'Mike Mitchell': 2,
#          'Jay Tavare': 2,
#          'Tomomichi Nishimura': 1,
#          'Omar J. Dorsey': 1,
#          'Kim Hidalgo': 1,
#          'Patrick St. Esprit': 1,
#          'Robin Thomas': 2,
#          'Annie Parisse': 2,
#          'Kika Markham': 1,
#          'Steve Railsback': 4,
#          'John Lithgow': 23,
#          'Lewis Fitz-Gerald': 1,
#          'Jennifer Lee': 1,
#          'Steve Martin': 38,
#          'Robin Harris': 1,
#          'Leslie Stefanson': 3,
#          'Sheri Wenden': 1,
#          'Penelope Milford': 1,
#          'Jeff Cohen': 2,
#          'Brad Hunt': 1,
#          'Nina Arianda': 3,
#          'James Logan': 1,
#          'Nancy Gates': 1,
#          'Lili Sepe': 1,
#          'Marcos Luna': 1,
#          'Patrick Malahide': 3,
#          'Ruben Santiago-Hudson': 1,
#          'Gary Sweet': 1,
#          'Kirron Kher': 1,
#          'Dallas Roberts': 8,
#          'Robert Hutton': 1,
#          'Michael E. Rodgers': 1,
#          'Ciar\xc3\x83\xc2\xa1n McMenamin': 2,
#          'Diana Kent': 1,
#          'Tom Berninger': 1,
#          'Conrad Vernon': 3,
#          'Robert Reich': 1,
#          'Marguerite Moreau': 4,
#          'Larissa Vereza': 1,
#          'Landon Pigg': 1,
#          'Kanoa Goo': 1,
#          'Gaku Hamada': 1,
#          'Eric Edelstein': 1,
#          'Keri Russell': 13,
#          'Ralph Lucas': 1,
#          'Joe Lewandowski': 1,
#          'Ernie Allo': 1,
#          'Marsha Mason': 4,
#          'Katrina Kaif': 6,
#          'Malachi Kirby': 2,
#          'Julie R. \xc3\x83\xcb\x9clgaard': 1,
#          'James Acheson': 1,
#          'Karen Kopins': 1,
#          'Charles Tyner': 1,
#          'Brooke Smith': 1,
#          'Bobby Darin': 1,
#          'Elizabeth Perkins': 13,
#          'Kieran Darcy-Smith': 1,
#          'Jean Ziegler': 1,
#          'Jing Lusi': 1,
#          'Jenson Button': 1,
#          'Dorla Bell': 1,
#          'Bruce Barry': 1,
#          'Sophie Stanton': 1,
#          'Adam Christie': 1,
#          'Andr\xc3\x83\xc2\xa9 the Giant': 1,
#          'Spencer Daniels': 1,
#          'Manu Tupou': 1,
#          'Nina Foch': 1,
#          'Matthew C. Martino': 1,
#          'Rufus Sewell': 13,
#          'Filip Peeters': 1,
#          'Terence Stamp': 13,
#          'Anna Maria Horsford': 3,
#          'Jeanne Dandoy': 1,
#          'Rie Miyazawa': 1,
#          'Jesco White': 1,
#          'Sinbad': 5,
#          'David Schofield': 3,
#          'Ronnie Kroell': 1,
#          'Christina Hendricks': 10,
#          'Steven R. McQueen': 1,
#          'Lisa Stansfield': 1,
#          'Kiely Williams': 5,
#          'Erbi Ago': 1,
#          'Mariah Bonner': 2,
#          'Sean Marshall': 1,
#          'Zana Briski': 1,
#          'Asher Keddie': 1,
#          'Litefoot': 2,
#          'Edward Clements': 1,
#          'Gillian Chung': 3,
#          'Mackenzie Rosman': 1,
#          'John DeLuca': 2,
#          'Fabiola Gianotti': 1,
#          'Jeffrey Jentzen': 1,
#          'Rudy Wurlitzer': 1,
#          'Zo\xc3\x83\xc2\xa9 De Grand Maison': 1,
#          'Steve Whitmire': 4,
#          'John Glover': 3,
#          'Richard Thomas': 2,
#          'Wendie Malick': 3,
#          'Ainsley Howard': 1,
#          'David Kelly': 2,
#          'Maura Tierney': 6,
#          'Dick Martin': 1,
#          'Jodelle Ferland': 7,
#          'Jerry Orbach': 8,
#          'Janet Margolin': 1,
#          'Brian Bedford': 2,
#          'James Sloyan': 1,
#          'David Hockney': 1,
#          'Jesse Welles': 1,
#          'Alexis Knapp': 3,
#          'Alyce LaTourelle': 1,
#          'Shawn Fanning': 1,
#          'Lance Gross': 3,
#          'Tomas von Br\xc3\x83\xc2\xb6mssen': 1,
#          'Kimberly Beck': 1,
#          'Oshri Cohen': 1,
#          'Mary Jo Smith': 1,
#          "Ottaviano Dell'Acqua": 1,
#          'Angela Merkel': 1,
#          'Dick Bradsell': 1,
#          'Darryn Lucio': 1,
#          'Chris Lowell': 2,
#          'Amanda Pays': 1,
#          'Nick Rotteveel': 1,
#          'Jeff Anderson': 3,
#          'Mohammad Bustami': 1,
#          'Tim Hodge': 2,
#          'Choi Min-sik': 1,
#          'Rusty Kelley': 1,
#          'Titus Welliver': 2,
#          'Penelope Mitchell': 2,
#          'Amy Acker': 4,
#          'John Reynolds': 1,
#          'Kristen Schaal': 4,
#          'Lu Feng': 1,
#          'Ken Radley': 1,
#          'Jane Birkin': 2,
#          'Cher': 8,
#          'Summer Bishil': 1,
#          'Marcellite Garner': 1,
#          'Ashanti': 2,
#          'Danny Midwinter': 4,
#          'David Bennent': 1,
#          'Jameson Parker': 2,
#          'Bob Peck': 1,
#          'Brittany Finamore': 1,
#          'Pat Mahoney': 1,
#          'Roy Blanchard': 1,
#          'Keegan Macintosh': 1,
#          'Agnieszka Grochowska': 1,
#          'Scott Innes': 4,
#          'Juan Pablo Medina': 1,
#          'Gina Carano': 4,
#          'Tim Conway': 5,
#          'Darryl Cooksey': 1,
#          'George Harrison': 8,
#          'Colin Ford': 2,
#          'Kathy Bates': 24,
#          'Nancy McDoniel': 1,
#          'Wung-hoe Gu': 1,
#          'Marc Wootton': 2,
#          'Adam David Thompson': 1,
#          'Claire Garvey': 1,
#          'Gerald Burke': 1,
#          'Cl\xc3\x83\xc2\xa9mence Po\xc3\x83\xc2\xa9sy': 6,
#          'Santiago Magill': 1,
#          'Ziggy Marley': 1,
#          'David Schwimmer': 10,
#          'Catherine Annette': 1,
#          'Kathryn McCormick': 2,
#          'Brad Smith': 1,
#          'Farhad Harun': 1,
#          'Zach Cregger': 1,
#          'Stefania Rocca': 2,
#          'Tsuyoshi Ihara': 2,
#          'Tara Buck': 1,
#          'Arthur Lowe': 1,
#          'Nancy Cartwright': 4,
#          'Pam Dawber': 1,
#          'Jason Marsden': 6,
#          'Audrey Tautou': 5,
#          'Graham Stark': 1,
#          'Mark Addy': 5,
#          'Wotan Wilke M\xc3\x83\xc2\xb6hring': 1,
#          'Leigh Lawson': 1,
#          'Shihori Kanjiya': 1,
#          'Samantha Cope': 1,
#          'Luke Albright': 1,
#          'Ruth Amarante': 1,
#          'Nicolas Maury': 1,
#          'Ken Davitian': 2,
#          'Jean-Yves Chatelais': 1,
#          'James Thomas': 1,
#          'Matthew Reese': 1,
#          'Jeff Shuter': 1,
#          'Phillip Adams': 1,
#          'Jane March': 3,
#          "Patrick O'Connor": 1,
#          'Jason Biggs': 13,
#          'Benedict Wong': 3,
#          'Gareth David-Lloyd': 1,
#          'Michael Coleman': 1,
#          'Ennis Esmer': 1,
#          'Josefia Forl\xc3\x83\xc2\xac': 1,
#          'John Judd': 1,
#          'Mena Suvari': 12,
#          'Fennie Yuen Kit-Ying': 2,
#          'Rita Moreno': 2,
#          'Dylan Sprouse': 1,
#          'Brenton Thwaites': 7,
#          'Lilly-Fleur Pointeaux': 1,
#          'Jake Stormoen': 3,
#          'James DeBello': 5,
#          'Greer Garson': 1,
#          "Gary 'Mani' Mounfield": 1,
#          'Wendie Jo Sperber': 1,
#          'Judith Anderson': 2,
#          'Brad Carter': 1,
#          'Nestor Aaron Absera': 1,
#          'Brian Spitz': 1,
#          'Kent McCord': 1,
#          'Eric Elmosnino': 3,
#          'Olivia Hussey': 4,
#          'Stocker Fontelieu': 1,
#          'John Harrington Bland': 1,
#          'Nyla McCarthy': 1,
#          'Darshan Kumaar': 1,
#          'Frank Overton': 2,
#          'John Hargrove': 1,
#          'William Kerwin': 1,
#          'Robert Hoffman': 2,
#          'Dalik Volonitz': 1,
#          'Wally Taylor': 1,
#          'Cris Campion': 1,
#          'Joe Bays': 1,
#          'Jason Wright': 1,
#          'Wilbur Wilde': 1,
#          'Robbie McIntosh': 1,
#          'Tom Asaki': 1,
#          'Jay Baker': 1,
#          'Fabrice Adde': 1,
#          ...})

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-00a35a2f1f9b> in <module>()
# ----> 1 most_common(flat_cast_list)
#
# NameError: name 'most_common' is not defined

# %%
clean_flat_cast_list = list(dict.fromkeys(flat_cast_list))
print(clean_flat_cast_list)
# Out:
# [nan, 'Takumi Yamazaki', 'Alex Zahara', 'Lilach Mendelovich', 'Vince Gilligan', 'Flavia Roberto', 'Jacki Weaver', 'Natalia Verbeke', 'Avis Bunnage', 'Olivia Stuck', 'Joe Alaskey', 'Juan Carlos Serr\xc3\x83\xc2\xa1n', 'Jimmy Clem', 'Kristen Hager', 'Andreas Wisniewski', 'Natalie Wood', 'Aaron Spann', 'James Le Gros', 'David Fox', 'Matthew Glave', 'Jemima West', 'Nicola Grupe', 'Fiona Press', 'Rodney Saulsberry', 'Fred Ewanuick', 'Cliff Robertson', 'Deke Garner', 'Marco Rodr\xc3\x83\xc2\xadguez', 'Sean Maher', 'Amanda Root', 'Yang Dong-geun', 'Ren\xc3\x83\xc2\xa9e Le Calm', 'Adam Fristoe', 'Joan Staley', 'Denis Lavant', 'Millen Baird', 'David Schallipp', 'Julie Kavner', 'Brian Austin Green', 'Vonetta McGee', 'Werner Herzog', 'Omar Benson Miller', 'Sterling Griffith', 'Michelle Page', 'Sergio Castellitto', 'Spencer Lofranco', 'Sho Kosugi', 'Lymari Nadal', 'Eamon Farren', 'Zach Cohen', 'Tonya Kay', 'Joie Lee', 'David Hoflin', 'Oona Chaplin', 'John Putch', 'Sydney Lassick', 'John Cho', 'Barbara Luddy', 'Stefania Casini', "Jermaine 'Huggy' Hopkins", 'Frank Alvarez', 'Robert Evans', 'Ed Quinn', 'Y\xc3\x83\xc2\xbbko Nakamura', 'Rica Fukami', 'Ashley Bashy Thomas', 'Mark Hadlow', 'Debra Deliso', 'Jonah Hill', 'Navin Nischol', 'Sanath Menon', 'Gabrielle Rose', 'Gabriel Congdon', 'Ken Lerner', 'Anne Twomey', 'Peter Boyden', 'Alice Levitt', 'Busta Rhymes', 'Dorien Thomas', 'John Waters', 'Jean Benguigui', 'Jessica Hinves', 'Anndi McAfee', 'Ari Folman', 'Mike Downey', 'Yvan Attal', 'Beau Brasso', 'Jhey Castles', 'Riley Griffiths', 'Simon Gleeson', 'Nicole Alonso', 'Erick Avari', 'Niall MacGinnis', 'Eric Window', 'Sarena Parmar', 'Pauly Shore', 'Rafi Gavron', 'Pam Cooke', 'Bobby Campo', 'Elena Anaya', 'Victor Webster', 'Sof\xc3\x83\xc2\xada Vergara', 'David Atrakchi', 'Elmyr de Hory', 'Sisca Jessica', 'Tim DeKay', 'Robyn Rikoon', 'Haaz Sleiman', 'Sidharth Malhotra', 'Skipp Sudduth', 'J\xc3\x83\xc2\xb3hann G. J\xc3\x83\xc2\xb3hannsson', 'Kate Reid', 'Carola Manzanares', 'Anne Bancroft', 'Amanda Grace Cooper', 'Geraldine James', 'Susan Jennifer Sullivan', 'Ritchie Allen', 'Lynne Griffin', 'Amy Linker', 'Jo Yang', "Jason O'Mara", 'Wil Wheaton', 'Noelle Parker', 'Sean Johnson', 'James Patrick Stuart', 'Peter van Eyck', 'Margaret Whiting', 'Anna Paquin', 'Ami Dolenz', 'Sigmund Vik', 'Basil Wallace', 'Rosemary Murphy', 'Samantha Morton', 'Christopher Heyerdahl', 'Morven Christie', 'Simona Maicanescu', 'Katee Sackhoff', 'Rajia Baroudi', 'James Caan', 'Megan Owen', 'Sam Raimi', 'Edo Van Breemen', 'Henry Brown', 'Jake La Botz', 'Mads Koudal', 'Tyra Banks', 'Thorley Walters', 'Jeananne Goossen', 'Will Geer', 'James Blackwell', 'Carel Struycken', 'Kim Seung-woo', 'Katie Parker', 'Clyde Lewis', 'Doug Bradley', 'Paul Kyrmse', 'Meshach Taylor', 'Jeremy Cooper', 'Justin Jon Ross', 'Sammy Leung', 'Sarah Ramos', 'Mandy-Rae Cruikshank', 'Josh Ethier', 'Chris Wylde', 'Abbey DiGregorio', 'Amber Jaeger', 'Joe Viterelli', "Fiona O'Shaughnessy", 'Tom Gilroy', 'Bitsie Tulloch', 'Sebastian Bach', 'Jos\xc3\x83\xc2\xa9 Z\xc3\x83\xc2\xba\xc3\x83\xc2\xb1iga', 'Graham Bushnell', 'Natalie Victoria', 'Alesandra Durham', 'Jason Lewis', 'Phyllis Munro', 'Marcia Cross', 'Caroline Chikezie', 'Dan Creed', 'Varg Vikernes', 'Darrel Guilbeau', 'Miiko Taka', 'Greg Siff', 'Margherita Buy', 'Gloria Foster', 'Brian Boland', 'Carolina G\xc3\x83\xc2\xb3mez', 'Chris Massoglia', 'Maren Jensen', 'Pell James', 'Warren Beatty', 'Jean Rougerie', 'Cullen Moss', 'Christopher Jordan Wallace', 'Jennifer Pudavick', 'Nick Faltas', 'Thandie Newton', 'Manuel Alexandre', 'Chris Demetral', 'Alex Datcher', 'Eriq La Salle', 'Anthony Sneed', 'Bogey', 'Christina Milian', 'Malala Yousafzai', 'Matthew Vandyke', '\xc3\x83\xe2\x80\x9cscar Jaenada', 'Emma Stone', 'Megumi Odaka', 'Mary-Charles Jones', 'Erik Knudsen', 'Logan Huffman', 'Paul McGillion', 'Percy Daggs III', 'Kelle Cantwell', 'Nora McMenamy', 'Stephen Amell', 'Pauline Moran', 'Ingvar Eggert Sigur\xc3\x83\xc2\xb0sson', 'Marley Shelton', 'Valin Shinye ...

# %%
len(clean_flat_cast_list)
# Out:
# 19028

# %%
#concat the two tables to add indivdual  columns on to the end of the dataframe
#this one for cast members
cast_concat = pd.concat([master_data, cast_names_split],axis=1)

cast_concat.head(5)
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# 0                      http://www.jurassicworld.com/   Colin Trevorrow
# 1                        http://www.madmaxmovie.com/     George Miller
# 2     http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
# 3  http://www.starwars.com/films/star-wars-episod...       J.J. Abrams
# 4                           http://www.furious7.com/         James Wan
#
#                          tagline       ...       vote_count vote_average  \
# 0              The park is open.       ...             5562          6.5
# 1             What a Lovely Day.       ...             6185          7.1
# 2     One Choice Can Destroy You       ...             2480          6.3
# 3  Every generation has a story.       ...             5292          7.5
# 4            Vengeance Hits Home       ...             2947          7.3
#
#    release_year    budget_adj   revenue_adj             cast1  \
# 0          2015  1.379999e+08  1.392446e+09       Chris Pratt
# 1          2015  1.379999e+08  3.481613e+08         Tom Hardy
# 2          2015  1.012000e+08  2.716190e+08  Shailene Woodley
# 3          2015  1.839999e+08  1.902723e+09     Harrison Ford
# 4          2015  1.747999e+08  1.385749e+09        Vin Diesel
#
#                  cast2             cast3               cast4           cast5
# 0  Bryce Dallas Howard       Irrfan Khan   Vincent D'Onofrio   Nick Robinson
# 1      Charlize Theron  Hugh Keays-Byrne      Nicholas Hoult     Josh Helman
# 2           Theo James      Kate Winslet        Ansel Elgort    Miles Teller
# 3          Mark Hamill     Carrie Fisher         Adam Driver    Daisy Ridley
# 4          Paul Walker     Jason Statham  Michelle Rodriguez  Dwayne Johnson
#
# [5 rows x 26 columns]

# %%
# shows how many rows have no cast data in this column
master_data['cast'].isnull().sum()

# %%
#group the data the vote average vote score
#this shows that in teh top 5 votes on one cast member is in each one so can look at those films to see the 'best scoring' cast members.

cast_concat.groupby(['vote_average'])['cast1','cast2','cast3','cast4','cast5'].count()

# %%
#group the data for for average vote score
#this shows the name for my hypothesis
cast_concat.groupby(['vote_average'])['cast1','cast2','cast3','cast4','cast5'].sum()

# %%
#top5 shows the top 5 voted movies and the cast mmebers attatched
#2 of these top 5 dont have cast memebers in 

top5= cast_concat.loc[cast_concat['vote_average'].isin([9.2,8.9,8.8,8.7,8.6])]
top5.head()

# %%
#create a new list of all the castfrom table above
cast_list_new = pd.concat([cast_concat['cast1'],cast_concat['cast2'],cast_concat['cast3'],cast_concat['cast4'],cast_concat['cast5']], ignore_index=True)

cast_list_new.head(25)

#possibley got duplicates

# %%
len(cast_list_new)
#with possibe duplicates

# %%
cast_list_new_df = pd.DataFrame(cast_list_new, columns = ['cast_member'])
cast_list_new_df.head()

#tern list into Dataframe

# %%
len(cast_list_new_df)
#length of data frame

# %%
cast_list_new_df.drop_duplicates(keep = False, inplace = True)
len(cast_list_new_df)

#remove dupilcates and length.

# %% [markdown]
# #### look up pandas expode to create new lines for each person in the cast clumn
# ### split cast members into a list inside the cast cell

# %%
#totals of the cast counts. 
cast_count = cast_list_new.value_counts()

print (cast_count)

# %%
len(cast_count)

# %%
cast_count_df = pd.DataFrame(cast_count, columns = ['count'])
cast_count_df.head()

# %%
#doesnt work as planned
#cast_avg_ern = pd.concat([cast_count_df,cast_concat]).groupby('revenue_adj')
#cast_avg_ern.head()

# %%
#cast_list_new is the list of all the cast members
#Loop through cast_concat looking in cast (using string contain)
##looking for the average 'revebue_adj' for each cast member.
#list the avg revenue for each cast member.

# %%
#this doesnt work

#cast=cast_list_new.value_counts().index
#for cast in cast:
#    cast_concat[cast] = cast_concat['cast'].str.contains(cast)
    
#cast_concat.head(1)

# %%
#Check this has worked on every data line. expected value is 10866

len(data_with_genres_split)

# %%
#change column names to more usefull not just 0-4

data_with_genres_split.columns = ['genre1','genre2','genre3','genre4','genre5']
data_with_genres_split.head()

# %%
#concat the two tables to add indivdual genres columns on to the end of the dataframe
genres_concat = pd.concat([master_data, data_with_genres_split],axis=1)

genres_concat.head(5)

# %%
#create a new list of all the genre values from table above
genre_list_new = pd.concat([genres_concat['genre1'],genres_concat['genre2'],genres_concat['genre3'],genres_concat['genre4'],genres_concat['genre5']], ignore_index=True)

genre_list_new.head()
len(genre_list_new)

# %%
#have alist now of all the readings. pass this list into a function into it.

# %%
#totals of the grenre counts. Drama is top of the list so i suspect this will be very common for most common genre
genre_count = genre_list_new.value_counts()

print (genre_count)

# %% [markdown]
# The data above states that Drama is the most popular genre over the sample times.
# More details in the conclusion

# %%
#Now sort the above list aphabeticaly
genre_sort = genre_count.rename_axis('genre')
genre_sort.sort_index(inplace = True)
print (genre_sort)

# %%
#For each genre add Ture or False if that genre is applicable to the row.
#genres_concat['Action'] = genres_concat['genres'].str.contains('Action')
#genres_concat['Adventure'] = genres_concat['genres'].str.contains('Adventure')
#genres_concat['Animation'] = genres_concat['genres'].str.contains('Animation')
#genres_concat['Comedy'] = genres_concat['genres'].str.contains('Comedy')
#genres_concat['Crime'] = genres_concat['genres'].str.contains('Crime')
#genres_concat['Documentary'] = genres_concat['genres'].str.contains('Documentary')
#genres_concat['Drama'] = genres_concat['genres'].str.contains('Drama')
#genres_concat['Family'] = genres_concat['genres'].str.contains('Family')
#genres_concat['Fantasy'] = genres_concat['genres'].str.contains('Fantasy')
#genres_concat['Foreign'] = genres_concat['genres'].str.contains('Foreign')
#genres_concat['History'] = genres_concat['genres'].str.contains('History')
#genres_concat['Horror'] = genres_concat['genres'].str.contains('Horror')
#genres_concat['Music'] = genres_concat['genres'].str.contains('Music')
#genres_concat['Mystery'] = genres_concat['genres'].str.contains('Mystery')
#genres_concat['Romance'] = genres_concat['genres'].str.contains('Romance')
#genres_concat['Science Fiction'] = genres_concat['genres'].str.contains('Science Fiction')
#genres_concat['TV Movie'] = genres_concat['genres'].str.contains('TV Movie')
#genres_concat['Thriller'] = genres_concat['genres'].str.contains('Thriller')
#genres_concat['War'] = genres_concat['genres'].str.contains('War')
#genres_concat['Western'] = genres_concat['genres'].str.contains('Western')


#genres_concat.head()

# %%
genres=genre_list_new.value_counts().index
for genre in genres:
    genres_concat[genre] = genres_concat['genres'].str.contains(genre)
    
genres_concat.head()

# %%
#group the data for each year
genres_concat.groupby(['release_year'])['Action','Adventure','Animation','Comedy','Crime', 'Documentary','Drama','Family','Fantasy','Foreign','History','Horror','Music','Mystery','Romance','Science Fiction','TV Movie','Thriller','War','Western'].sum()

# %%
#create a new data frame with the desiered info
genre_answer = genres_concat.groupby(['release_year'])['Action','Adventure','Animation','Comedy','Crime', 'Documentary','Drama','Family','Fantasy','Foreign','History','Horror','Music','Mystery','Romance','Science Fiction','TV Movie','Thriller','War','Western'].sum()

# %%
genre_answer.head()

# %%
#run code to find the max value for each row
genre_answer.idxmax(axis=1)

# %%
#Chart to show the most common genrea through out the total data set
# %matplotlib inline
genre_count.plot.bar(figsize=(18, 16),title=('Most Common Genre'))

# %%
#plot the occurance of each genre per year
# %matplotlib inline
genre_answer.plot.line(figsize=(18,16))

# %% [markdown]
# Conclusion:
#
# 1d analysis - Drama is the most popular genre of the time period.
#
# 2d analysis - The most popular genre by year is drama except for the following years where it is comedy (1963, 1966, 1967, 1985, 1987 , 1988, 1989, 1994,2001, 2003)
#
# Assumption/limitations there are 23 entrys of data where there is no Genre data. This means 2 % of all data is missing. This is a very low percntage and i am happ my colculsion will still stand.
#
# The answer to the question over all is Drama is the most common genre.
# The table "genre_answer" shows for each year which was the most popular genre.
